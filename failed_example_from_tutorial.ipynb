# %%
# %load_ext zipline

# %%
# %%zipline --start 2016-1-1 --end 2018-1-1 --no-benchmark
# from zipline.api import symbol, order, record
#
# def initialize(context):
#     pass
#
# def handle_data(context, data):
#     order(symbol('AAPL'), 10)
#     record(AAPL=data[symbol('AAPL')].price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/24/gd3jmlj15mv_ytrmxncmjdbm0000gp/T/ipykernel_50570/739833824.py in <module>
# ----> 1 get_ipython().run_cell_magic('zipline', '--start 2016-1-1 --end 2018-1-1 --no-benchmark', "from zipline.api import symbol, order, record\n\ndef initialize(context):\n    pass\n\ndef handle_data(context, data):\n    order(symbol('AAPL'), 10)\n    record(AAPL=data[symbol('AAPL')].price)\n")
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# -> 2419                 result = fn(*args, **kwargs)
#    2420             return result
#    2421
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/__main__.py in zipline_magic(line, cell)
#     333     )
#     334     try:
# --> 335         return run.main(
#     336             # put our overrides at the start of the parameter list so that
#     337             # users may pass values with higher precedence
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/click/core.py in main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    1051             try:
#    1052                 with self.make_context(prog_name, args, **extra) as ctx:
# -> 1053                     rv = self.invoke(ctx)
#    1054                     if not standalone_mode:
#    1055                         return rv
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/click/core.py in invoke(self, ctx)
#    1393
#    1394         if self.callback is not None:
# -> 1395             return ctx.invoke(self.callback, **ctx.params)
#    1396
#    1397     def shell_complete(self, ctx: Context, incomplete: str) -> t.List["CompletionItem"]:
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/click/core.py in invoke(_Context__self, _Context__callback, *args, **kwargs)
#     752         with augment_usage_errors(__self):
#     753             with ctx:
# --> 754                 return __callback(*args, **kwargs)
#     755
#     756     def forward(
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/click/decorators.py in new_func(*args, **kwargs)
#      24
#      25     def new_func(*args, **kwargs):  # type: ignore
# ---> 26         return f(get_current_context(), *args, **kwargs)
#      27
#      28     return update_wrapper(t.cast(F, new_func), f)
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/__main__.py in run(ctx, algofile, algotext, define, data_frequency, capital_base, bundle, bundle_timestamp, benchmark_file, benchmark_symbol, benchmark_sid, no_benchmark, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, blotter)
#     298     )
#     299
# --> 300     return _run(
#     301         initialize=None,
#     302         handle_data=None,
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/utils/run_algo.py in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, environ, blotter, custom_loader, benchmark_spec)
#     198
#     199     try:
# --> 200         perf = TradingAlgorithm(
#     201             namespace=namespace,
#     202             data_portal=data,
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/algorithm.py in run(self, data_portal)
#     621         try:
#     622             perfs = []
# --> 623             for perf in self.get_generator():
#     624                 perfs.append(perf)
#     625
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/gens/tradesimulation.py in transform(self)
#     226             for dt, action in self.clock:
#     227                 if action == BAR:
# --> 228                     for capital_change_packet in every_bar(dt):
#     229                         yield capital_change_packet
#     230                 elif action == SESSION_START:
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/gens/tradesimulation.py in every_bar(dt_to_use, current_data, handle_data)
#     141                 metrics_tracker.process_commission(commission)
#     142
# --> 143             handle_data(algo, current_data, dt_to_use)
#     144
#     145             # grab any new orders from the blotter, then clear the list.
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/utils/events.py in handle_data(self, context, data, dt)
#     204         with self._create_context(data):
#     205             for event in self._events:
# --> 206                 event.handle_data(
#     207                     context,
#     208                     data,
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/utils/events.py in handle_data(self, context, data, dt)
#     227         """
#     228         if self.rule.should_trigger(dt):
# --> 229             self.callback(context, data)
#     230
#     231
#
# ~/.local/share/virtualenvs/at4ml-b_TllNFg/lib/python3.9/site-packages/zipline/algorithm.py in handle_data(self, data)
#     444     def handle_data(self, data):
#     445         if self._handle_data:
# --> 446             self._handle_data(self, data)
#     447
#     448     def analyze(self, perf):
#
# <algorithm> in handle_data(context, data)
#
# TypeError: 'zipline._protocol.BarData' object is not subscriptable
