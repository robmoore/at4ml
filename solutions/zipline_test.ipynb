# %% [markdown]
# # Zipline Installation: Bundle Ingest & Algorithm Test

# %% [markdown]
# ## Imports and Settings

# %% [markdown]
# We don't need much here since the imports all take place in the cell where we formulate the algorithm.

# %%
# %matplotlib inline

# %% [markdown]
# ## Load Zipline extension

# %% [markdown]
# Enable the algorithm execution.

# %%
# %load_ext zipline

# %% [markdown]
# ## Ingest Data

# %%
# !zipline ingest -b quandl
# Out:
# [2021-05-05 13:54:59.388658] INFO: zipline.data.bundles.core: Ingesting quandl.
# [2021-05-05 13:54:59.388757] INFO: zipline.data.bundles.quandl: Downloading WIKI metadata.
# Downloading WIKI Prices table from Quandl  [####################################]  100%
# [2021-05-05 13:55:39.744942] INFO: zipline.data.bundles.quandl: Parsing raw data.
# [2021-05-05 13:55:57.732381] INFO: zipline.data.bundles.quandl: Generating asset metadata.
# Merging daily equity files:  [---------------#--------------------]  1731/home/stefan/.pyenv/versions/miniconda3-latest/envs/ml4t/lib/python3.8/site-packages/zipline/data/bcolz_daily_bars.py:366: UserWarning: Ignoring 1 values because they are out of bounds for uint32:             open  high   low  close        volume  ex_dividend  split_ratio
# 2011-04-11  1.79  1.84  1.55    1.7  6.674913e+09          0.0          1.0
#   winsorise_uint32(raw_data, invalid_data_behavior, "volume", *OHLC)
# Merging daily equity files:  [####################################]
# [2021-05-05 13:57:22.122192] INFO: zipline.data.bundles.quandl: Parsing split data.
# [2021-05-05 13:57:22.212260] INFO: zipline.data.bundles.quandl: Parsing dividend data.
# [2021-05-05 13:57:23.965940] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=67, ex_date=2017-11-09, amount=0.620
# [2021-05-05 13:57:23.966061] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=93, ex_date=2017-11-09, amount=0.240
# [2021-05-05 13:57:23.966106] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=161, ex_date=2017-11-09, amount=0.110
# [2021-05-05 13:57:23.966143] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=283, ex_date=2017-11-09, amount=0.415
# [2021-05-05 13:57:23.966177] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=298, ex_date=2017-11-09, amount=1.420
# [2021-05-05 13:57:23.966211] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=318, ex_date=2017-11-09, amount=0.330
# [2021-05-05 13:57:23.966244] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=434, ex_date=2017-11-09, amount=0.110
# [2021-05-05 13:57:23.966276] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=516, ex_date=1996-05-30, amount=0.310
# [2021-05-05 13:57:23.966309] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=524, ex_date=2017-11-09, amount=0.050
# [2021-05-05 13:57:23.966351] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=556, ex_date=2017-11-09, amount=0.075
# [2021-05-05 13:57:23.966396] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=578, ex_date=2017-11-09, amount=0.160
# [2021-05-05 13:57:23.966429] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=605, ex_date=2017-11-09, amount=0.040
# [2021-05-05 13:57:23.966462] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=666, ex_date=1990-03-26, amount=0.140
# [2021-05-05 13:57:23.966494] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=694, ex_date=1990-03-27, amount=0.100
# [2021-05-05 13:57:23.966527] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=723, ex_date=2017-11-09, amount=1.620
# [2021-05-05 13:57:23.966559] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=758, ex_date=2017-11-09, amount=0.500
# [2021-05-05 13:57:23.966591] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=788, ex_date=2017-11-09, amount=0.060
# [2021-05-05 13:57:23.966623] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=859, ex_date=1995-05-09, amount=0.100
# [2021-05-05 13:57:23.966661] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=904, ex_date=2017-11-09, amount=0.135
# [2021-05-05 13:57:23.966693] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=975, ex_date=2017-11-09, amount=0.030
# [2021-05-05 13:57:23.966725] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1057, ex_date=2017-11-09, amount=0.250
# [2021-05-05 13:57:23.966757] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1088, ex_date=1990-03-26, amount=0.240
# [2021-05-05 13:57:23.966789] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1091, ex_date=2017-11-09, amount=0.075
# [2021-05-05 13:57:23.966821] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1111, ex_date=1993-03-04, amount=0.070
# [2021-05-05 13:57:23.966853] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1172, ex_date=2017-11-09, amount=0.130
# [2021-05-05 13:57:23.966885] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1209, ex_date=2017-11-09, amount=0.010
# [2021-05-05 13:57:23.966917] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1322, ex_date=1995-05-25, amount=0.150
# [2021-05-05 13:57:23.966949] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1441, ex_date=2017-11-09, amount=1.500
# [2021-05-05 13:57:23.966980] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1525, ex_date=2017-11-09, amount=0.090
# [2021-05-05 13:57:23.967012] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1600, ex_date=2015-07-06, amount=16.500
# [2021-05-05 13:57:23.967045] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1642, ex_date=2017-11-09, amount=0.270
# [2021-05-05 13:57:23.967077] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1748, ex_date=2017-11-09, amount=0.740
# [2021-05-05 13:57:23.967108] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1876, ex_date=2017-11-09, amount=0.120
# [2021-05-05 13:57:23.967140] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1922, ex_date=2017-11-09, amount=0.040
# [2021-05-05 13:57:23.967172] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1947, ex_date=1990-03-26, amount=0.150
# [2021-05-05 13:57:23.967204] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2098, ex_date=2017-11-09, amount=0.200
# [2021-05-05 13:57:23.967235] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2118, ex_date=2014-11-06, amount=0.050
# [2021-05-05 13:57:23.967267] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2120, ex_date=2017-11-09, amount=0.110
# [2021-05-05 13:57:23.967299] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2149, ex_date=2017-11-09, amount=0.330
# [2021-05-05 13:57:23.967330] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2204, ex_date=2017-11-09, amount=0.320
# [2021-05-05 13:57:23.967362] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2220, ex_date=2017-11-09, amount=0.660
# [2021-05-05 13:57:23.967393] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2281, ex_date=2017-11-09, amount=0.450
# [2021-05-05 13:57:23.967424] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2389, ex_date=2017-11-09, amount=0.140
# [2021-05-05 13:57:23.967455] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2441, ex_date=2017-11-09, amount=0.215
# [2021-05-05 13:57:23.967487] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2517, ex_date=2017-11-09, amount=0.080
# [2021-05-05 13:57:23.967519] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2582, ex_date=2017-11-09, amount=0.780
# [2021-05-05 13:57:23.967551] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2622, ex_date=2017-11-09, amount=0.390
# [2021-05-05 13:57:23.967582] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2662, ex_date=2015-01-14, amount=0.750
# [2021-05-05 13:57:23.967614] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2000-12-27, amount=0.250
# [2021-05-05 13:57:23.967645] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2009-09-11, amount=0.420
# [2021-05-05 13:57:23.967677] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2009-12-11, amount=0.420
# [2021-05-05 13:57:23.967708] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2010-03-11, amount=0.420
# [2021-05-05 13:57:23.967740] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2010-12-15, amount=0.180
# [2021-05-05 13:57:23.967771] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2766, ex_date=2017-11-09, amount=0.320
# [2021-05-05 13:57:23.967803] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2798, ex_date=2017-11-09, amount=0.065
# [2021-05-05 13:57:23.967834] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2817, ex_date=1992-03-03, amount=0.300
# [2021-05-05 13:57:23.967866] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2824, ex_date=2017-11-09, amount=0.120
# [2021-05-05 13:57:23.967897] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2843, ex_date=2017-11-09, amount=0.150
# [2021-05-05 13:57:23.967929] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2857, ex_date=2011-09-07, amount=0.410
# [2021-05-05 13:57:23.967961] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2968, ex_date=1990-03-26, amount=0.100
# [2021-05-05 13:57:23.967992] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3005, ex_date=1990-03-26, amount=0.070
# [2021-05-05 13:57:23.968024] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3078, ex_date=2014-05-12, amount=0.060
# [2021-05-05 13:57:23.968055] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3117, ex_date=2017-11-09, amount=0.430
# [2021-05-05 13:57:23.968086] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3138, ex_date=2010-08-16, amount=0.060
# [2021-05-05 13:57:23.968118] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3145, ex_date=2017-11-09, amount=0.050
# [2021-05-05 13:57:23.968293] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=501, ex_date=2006-01-03, amount=41.560
# [2021-05-05 13:57:23.968331] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1557, ex_date=2007-07-02, amount=88.530
# [2021-05-05 13:57:23.968364] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1632, ex_date=2000-07-13, amount=181.000
# [2021-05-05 13:57:23.968397] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1657, ex_date=2013-09-30, amount=21.355
# [2021-05-05 13:57:23.968429] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1775, ex_date=1994-12-01, amount=76.000
# [2021-05-05 13:57:23.968461] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1776, ex_date=1996-11-04, amount=36.708
# [2021-05-05 13:57:23.968493] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=2455, ex_date=2016-10-03, amount=25.611
# [2021-05-05 13:57:23.968525] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=2687, ex_date=2008-06-26, amount=10.000
# [2021-05-05 13:57:23.968558] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=2900, ex_date=2007-07-02, amount=88.530
# [2021-05-05 13:57:23.968590] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=3088, ex_date=2015-04-27, amount=31.291

# %% [markdown]
# ## Run a simple test algorithm

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 -o dma.pickle --no-benchmark
#
# from zipline.api import order_target, record, symbol
# import matplotlib.pyplot as plt
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.loc[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.tight_layout()
# Out:
# /home/stefan/.pyenv/versions/miniconda3-latest/envs/ml4t/lib/python3.8/site-packages/empyrical/stats.py:706: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(
# /home/stefan/.pyenv/versions/miniconda3-latest/envs/ml4t/lib/python3.8/site-packages/empyrical/stats.py:797: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(average_annual_return, annualized_downside_risk, out=out)
#                                         period_open              period_close transactions  starting_cash                                          positions   ending_cash orders  portfolio_value    pnl  longs_count  ...  benchmark_volatility  algo_volatility  alpha  beta    sharpe   sortino  max_drawdown    AAPL  short_mavg   long_mavg
# 2014-01-02 21:00:00+00:00 2014-01-02 14:31:00+00:00 2014-01-02 21:00:00+00:00           []   1.000000e+07                                                 []  1.000000e+07     []     1.000000e+07    0.0            0  ...                   NaN              NaN   None  None       NaN       NaN      0.000000     NaN         NaN         NaN
# 2014-01-03 21:00:00+00:00 2014-01-03 14:31:00+00:00 2014-01-03 21:00:00+00:00           []   1.000000e+07                                                 []  1.000000e+07     []     1.000000e+07    0.0            0  ...                   0.0         0.000000   None  None       NaN       NaN      0.000000     NaN         NaN         NaN
# 2014-01-06 21:00:00+00:00 2014-01-06 14:31:00+00:00 2014-01-06 21:00:00+00:00           []   1.000000e+07                                                 []  1.000000e+07     []     1.000000e+07    0.0            0  ...                   0.0         0.000000   None  None       NaN       NaN      0.000000     NaN         NaN         NaN
# 2014-01-07 21:00:00+00:00 2014-01-07 14:31:00+00:00 2014-01-07 21:00:00+00:00           []   1.000000e+07                                                 []  1.000000e+07     []     1.000000e+07    0.0            0  ...                   0.0         0.000000   None  None       NaN       NaN      0.000000     NaN         NaN         NaN
# 2014-01-08 21:00:00+00:00 2014-01-08 14:31:00+00:00 2014-01-08 21:00:00+00:00           []   1.000000e+07                                                 []  1.000000e+07     []     1.000000e+07    0.0            0  ...                   0.0         0.000000   None  None       NaN       NaN      0.000000     NaN         NaN         NaN
# ...                                             ...                       ...          ...            ...                                                ...           ...    ...              ...    ...          ...  ...                   ...              ...    ...   ...       ...       ...           ...     ...         ...         ...
# 2017-12-22 21:00:00+00:00 2017-12-22 14:31:00+00:00 2017-12-22 21:00:00+00:00           []   9.987736e+06  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...  9.987736e+06     []     1.000524e+07    0.0            1  ...                   0.0         0.000191   None  None  0.687600  1.012820     -0.000295  175.01  163.442190  142.891860
# 2017-12-26 21:00:00+00:00 2017-12-26 14:31:00+00:00 2017-12-26 21:00:00+00:00           []   9.987736e+06  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...  9.987736e+06     []     1.000479e+07 -444.0            1  ...                   0.0         0.000193   None  None  0.624704  0.913225     -0.000295  170.57  163.598280  143.075387
# 2017-12-27 21:00:00+00:00 2017-12-27 14:31:00+00:00 2017-12-27 21:00:00+00:00           []   9.987736e+06  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...  9.987736e+06     []     1.000480e+07    3.0            1  ...                   0.0         0.000192   None  None  0.624784  0.913342     -0.000295  170.60  163.746503  143.259273
# 2017-12-28 21:00:00+00:00 2017-12-28 14:31:00+00:00 2017-12-28 21:00:00+00:00           []   9.987736e+06  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...  9.987736e+06     []     1.000484e+07   48.0            1  ...                   0.0         0.000192   None  None  0.630682  0.922021     -0.000295  171.08  163.899520  143.445907
# 2017-12-29 21:00:00+00:00 2017-12-29 14:31:00+00:00 2017-12-29 21:00:00+00:00           []   9.987736e+06  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...  9.987736e+06     []     1.000466e+07 -185.0            1  ...                   0.0         0.000193   None  None  0.605565  0.884195     -0.000295  169.23  163.997280  143.626570
#
# [1007 rows x 40 columns]
